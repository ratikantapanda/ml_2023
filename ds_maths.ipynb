# %%
# !pip install sympy

# %%
from sympy import Symbol, cos, plot

# %%
x = Symbol('x')
f = 2*x + 10
plot(f)

# %%
f = x**2
plot(f)

# %%
f = x**2 + 1
plot(f)

# %%
from sympy.plotting import plot3d
from sympy import symbols

# %%
x,y = symbols('x y')
f = 2*x + 3*y
plot3d(f)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 plot(range(10))
#
# File /usr/local/anaconda3/envs/ds_env/lib/python3.10/site-packages/sympy/plotting/plot.py:1869, in plot(show, *args, **kwargs)
#    1867 series = []
#    1868 plot_expr = check_arguments(args, 1, 1)
# -> 1869 series = [LineOver1DRangeSeries(*arg, **kwargs) for arg in plot_expr]
#    1871 plots = Plot(*series, **kwargs)
#    1872 if show:
#
# TypeError: 'NoneType' object is not iterable
